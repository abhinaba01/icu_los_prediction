# %% [markdown]
# # Hempel Replication
#
# Use `python scripts/run_hempel.py` for the canonical run.

# %%
from pathlib import Path
import pandas as pd
feature_path = Path('data/processed/hempel_features.parquet')
features = pd.read_parquet(feature_path) if feature_path.exists() else None
features.shape if features is not None else 'Run scripts/run_hempel.py first'

# %% [markdown]
# # Ablation Study
#
# Use `python scripts/run_ablation.py` after Hempel and extended runs complete.

# %%
from pathlib import Path
import pandas as pd
delta_path = Path('results/ablation/tables/table6_delta_metrics.csv')
pd.read_csv(delta_path).head() if delta_path.exists() else 'Run scripts/run_ablation.py first'

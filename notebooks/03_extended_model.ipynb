# %% [markdown]
# # Extended Model
#
# Use `python scripts/run_extended.py` to add occupancy features with the shared split.

# %%
from pathlib import Path
import pandas as pd
feature_path = Path('data/processed/extended_features.parquet')
features = pd.read_parquet(feature_path) if feature_path.exists() else None
features.filter(regex='occupancy|concurrent').head() if features is not None else 'Run scripts/run_extended.py first'
